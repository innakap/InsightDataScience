# %%
import pandas as pd

path = "/Users/mkapilev/Documents/Insight/Project_databases/survey_data/csv/demographic-snapshot-2015-16-to-2019-20-(public).csv"
enrollmentDF = pd.read_csv(path)
enrollmentDF = enrollmentDF[['DBN', 'School Name', 'Year', 'Total Enrollment', 'Economic Need Index', 'Enrollment Change']]
enrollmentDF = enrollmentDF[(enrollmentDF['Year'] != '2019-20')] # filter out last year 2020 - we don't have data for it
enrollmentDF
# Out:
#          DBN                               School Name     Year  \
# 0     01M015                 P.S. 015 Roberto Clemente  2015-16
# 1     01M015                 P.S. 015 Roberto Clemente  2016-17
# 2     01M015                 P.S. 015 Roberto Clemente  2017-18
# 3     01M015                 P.S. 015 Roberto Clemente  2018-19
# 5     01M019                       P.S. 019 Asher Levy  2015-16
# ...      ...                                       ...      ...
# 9089  84X718  Bronx Charter School for Better Learning  2018-19
# 9091  84X730         Bronx Charter School for the Arts  2015-16
# 9092  84X730         Bronx Charter School for the Arts  2016-17
# 9093  84X730         Bronx Charter School for the Arts  2017-18
# 9094  84X730         Bronx Charter School for the Arts  2018-19
#
#      Total Enrollment Economic Need Index  Enrollment Change
# 0                 176              88.90%           0.011364
# 1                 178              88.20%           0.067416
# ...

# %%
import pandas as pd

parentSurveyDF = pd.read_excel('/Users/mkapilev/Documents/Insight/Project_databases/survey_data/xlsx/2019-public-data-file_parent.xlsx', sheet_name='Parent % Pos & Neg %')
parentSurveyDF['Year']='2018-19'
#parentSurveyDF

unnamedCols = []

for col in parentSurveyDF.columns: 
    if col.startswith("Unnamed:"):
        unnamedCols.append(col)

parentSurveyDF = parentSurveyDF.drop(columns=unnamedCols)
parentSurveyDF.drop([0,1], inplace=True)
parentSurveyDF
# Out:
#          DBN                                     School Name  \
# 2     01M015                       P.S. 015 ROBERTO CLEMENTE
# 3     01M019                             P.S. 019 ASHER LEVY
# 4     01M020                            P.S. 020 ANNA SILVER
# 5     01M034                  P.S. 034 FRANKLIN D. ROOSEVELT
# 6     01M063                       THE STAR ACADEMY - P.S.63
# ...      ...                                             ...
# 2943    Z123         MOSAIC PRE-K CENTER AT 54-25 101 STREET
# 2944    Z124     MOSAIC PRE-K CENTER AT 104-04 CORONA AVENUE
# 2945    Z125  MOSAIC PRE-K CENTER AT 108-18 ROOSEVELT AVENUE
# 2946    Z126   DISTRICT 27 PRE-K CENTER AT 103-02 101 AVENUE
# 2947    Z127  DISTRICT 27 PRE-K CENTER AT 133-40 79TH STREET
#
#       Total Parent Response Rate  \
# 2                           91.0
# 3                          100.0
# 4                           58.0
# 5                           29.0
# 6                           80.0
# ...

# %%
joinedDF = enrollmentDF.merge(parentSurveyDF, how='inner', left_on=['DBN', 'Year'], right_on=['DBN', 'Year'])

for col in joinedDF.columns:
    print(col)
# Out:
# DBN
# School Name_x
# Year
# Total Enrollment
# Economic Need Index
# Enrollment Change
# School Name_y
# Total Parent Response Rate
# 1a. School staff regularly communicate with me about how I can help my child learn.
# 1b.  My child's school offers me opportunities to visit my child's classroom, such as observing instruction, participating in an activity with my child, etc.
# 1c. My child’s school offers me the opportunity to volunteer time to support this school (for example, helping in classrooms, helping with school-wide events, etc.).
# 1d. I am greeted warmly when I call or visit the school.
# 1e. Teachers work closely with me to meet my child's needs.
# 1f. I feel well-informed by the communications I receive from my child's school.
# 1g. I feel respected by my child's teachers.
# 1h. Staff at this school work hard to build trusting relationships with parents/guardians like me.
# 1i. My child's school communicates with me in a language and in a way that I can understand.
# ...

# %%
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)

accuracy = model.score(X_test, y_test)
print(f"Accuracy: {accuracy}")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
